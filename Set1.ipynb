# %%
list = [10,8,1,0,27,7]
Minimum = min(list)
Maximum = max(list)
print("Largest Number From List is:",Maximum)
print("Smallest Numbert From List is:",Minimum)
# Out:
# Largest Number From List is: 27
# Smallest Numbert From List is: 0

# %%
list = [1,2,3,5,6,7,9,8]
for num in list:
    if num % 2 == 0:
       print(num,"Even")
    else:
       print(num,"Odd")
# Out:
# 1 Odd
# 2 Even
# 3 Odd
# 5 Odd
# 6 Even
# 7 Odd
# 9 Odd
# 8 Even

# %%
list = [1,20,30,1,7,9,7]

list.remove(7)
list.remove(1)
print(list)
# Out:
# [20, 30, 1, 9, 7]

# %%
lst = [1, 20, 30, 1, 7, 9, 7]

new_list = []

for element in lst:
    if element not in new_list:
        new_list.append(element)

print(new_list)
# Out:
# [1, 20, 30, 7, 9]
